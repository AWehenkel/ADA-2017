# %%
import pandas as pd
import sqlite3
from PythonSrc import *

# %load_ext autoreload
# %autoreload 2

# %%
DATA_PATH = "MillionSong/" 
DATA_SUBSET = DATA_PATH + "AdditionalFilesSubset/"
DATA_FULL = DATA_PATH + "AdditionalFiles/"

# %%
h5s = open_h5_file_read("MillionSong/data/B/F/L/TRBFLER128F148C52B.h5")

# %%
h5s
#fill_hdf5_from_track(h5s, DATA_SUBSET + "subset_unique_tracks")

# %%
get_segments_start(h5s, 9500)

# %%
msd_summary_file = pd.HDFStore(DATA_SUBSET + "subset_msd_summary_file.h5")
msd_summary_file
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: MillionSong/AdditionalFilesSubset/subset_msd_summary_file.h5
# /analysis/songs               frame_table [0.0.0] (typ->generic,nrows->10000,ncols->31,indexers->[index],dc->[analysis_sample_rate,audio_md5,danceability,duration,end_of_fade_in,energy,idx_bars_confidence,idx_bars_start,idx_beats_confidence,idx_beats_start,idx_sections_confidence,idx_sections_start,idx_segments_confidence,idx_segments_loudness_max,idx_segments_loudness_max_time,idx_segments_loudness_start,idx_segments_pitches,idx_segments_start,idx_segments_timbre,idx_tatums_confidence,idx_tatums_start,key,key_confidence,loudness,mode,mode_confidence,start_of_fade_out,tempo,time_signature,time_signature_confidence,track_id])
# ...

# %%
tmp = msd_summary_file.get('/analysis/songs')
#tmp1['track_7digitalid'] = tmp1['track_7digitalid'].astype(str)
#tmp1[tmp1.track_7digitalid == '3401791']

# %%
tmp.head()
# Out:
#    analysis_sample_rate                         audio_md5  danceability  \
# 0                 22050  a600d65cf157a306be60f26ecbf218f4           0.0
# 1                 22050  c64d75b0588e5ab552ee94548b50a4fa           0.0
# 2                 22050  0cadd310865701bb93ced1cd78e8910a           0.0
# 3                 22050  14be4fc1170152c445b3be7b8d18dfec           0.0
# 4                 22050  1def5d8298e8cb29a188a5a7c0e9429a           0.0
#
#     duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 0  280.21506           0.238     0.0                    0               0
# 1  191.68608           0.000     0.0                    0               0
# 2  222.92853           0.000     0.0                    0               0
# 3  278.38649           0.496     0.0                    0               0
# 4   89.15546           4.847     0.0                    0               0
#
#    idx_beats_confidence  idx_beats_start         ...          key  \
# ...

# %%
tmp1 = msd_summary_file.get('/metadata/songs')
tmp1.head()
# Out:
#   analyzer_version  artist_7digitalid  artist_familiarity  artist_hotttnesss  \
# 0                               29785            0.780462           0.574275
# 1                              167867            0.561590           0.420570
# 2                                7725            0.687687           0.406686
# 3                                2799            0.391741           0.291265
# 4                               74269            0.593416           0.395710
#
#             artist_id  artist_latitude  \
# 0  ARMQHX71187B9890D3              NaN
# 1  AR2PT4M1187FB55B1A              NaN
# 2  ARDI88R1187B98DAB2              NaN
# 3  ARUKJUP12086C14589              NaN
# 4  ARZEWUR1187FB53DC8         50.45663
#
#                                 artist_location  artist_longitude  \
# 0                                   Atlanta, GA               NaN
# 1                                                             NaN
# ...

# %%
tmp2 = msd_summary_file.get('/musicbrainz/songs')

# %%
asg = msd_summary_file.get('/analysis/songs')
asg.columns

# %%
msd_summary_file_comp = pd.HDFStore(DATA_FULL + "msd_summary_file.h5")

# %%
metadata_sg = msd_summary_file_comp.get('/metadata/songs')

# %%
metadata_sg.head()
# Out:
#   analyzer_version  artist_7digitalid  artist_familiarity  artist_hotttnesss  \
# 0                                4069            0.649822           0.394032
# 1                              113480            0.439604           0.356992
# 2                               63531            0.643681           0.437504
# 3                               65051            0.448501           0.372349
# 4                              158279            0.000000           0.000000
#
#             artist_id  artist_latitude    artist_location  artist_longitude  \
# 0  ARYZTJS1187B98C555              NaN                                  NaN
# 1  ARMVN3U1187FB3A1EB              NaN                                  NaN
# 2  ARGEKB01187FB50750          55.8578  Glasgow, Scotland          -4.24251
# 3  ARNWYLR1187B9B2F9C              NaN                                  NaN
# 4  AREQDTE1269FB37231              NaN                                  NaN
#
# ...

# %%
ana_sg = msd_summary_file_comp.get('/analysis/songs')

# %%
ana_sg.head()
ana_sg.columns

# %%
ana_sg[ana_sg.danceability == 0.0].shape

# %%
cnx = sqlite3.connect(DATA_FULL + 'track_metadata.db')

# %%
print(pd.read_sql_query("select * from songs limit 0,1", cnx))
